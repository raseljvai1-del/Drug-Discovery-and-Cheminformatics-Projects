# %% [markdown]
# ## Drug Discovery & Cheminformatics Projects.
#
# ```Text
#                     DRUG DISCOVERY
#                          │
#           ┌──────────────┴──────────────┐
#           │                             │
#        Biology                      Chemistry
#           │                             │
#      Target ID                    Molecules
#           │                             │
#      Structure                    Descriptors
#           │                             │
#      Binding Site                Fingerprints
#           │                             │
#      Docking                     Similarity
#           │                             │
#      Screening                   SAR
#           │                             │
#           └──────────────┬──────────────┘
#                          │
#                   Lead Optimization
#                          │
#                   QSAR / ML / DL
#                          │
#                        ADMET
#                          │
#                   Multi-objective
#                     optimization
#                          │
#                   Generative AI
#                          │
#                  Novel Molecules
#                          │
#                  Experimental Test
#                          │
#                     DMTA Cycle
# ```
#
# ### Level 1 — Cheminformatics Fundamentals
#
# | #  | Topics                                      | Main Concepts                               | Tools                           |
# | -- | --------------------------------------------- | ------------------------------------------- | ------------------------------- |
# | 1  | **Molecule Explorer**                         | SMILES, molecular structure, atoms/bonds    | RDKit                           |
# | 2  | **SMILES → 2D Molecular Structure Generator** | SMILES parsing, visualization               | RDKit                           |
# | 3  | **SMILES → Molecular Properties Calculator**  | MW, LogP, TPSA, HBD, HBA                    | RDKit                           |
# | 4  | **Molecular Descriptor Calculator**           | Descriptors & physicochemical properties    | RDKit, Pandas                   |
# | 5  | **Drug-Likeness Checker**                     | Lipinski Rule of Five                       | RDKit                           |
# | 6  | **Molecule Fingerprint Generator**            | Morgan/ECFP fingerprints                    | RDKit                           |
# | 7  | **Molecular Similarity Search Engine**        | Tanimoto similarity                         | RDKit                           |
# | 8  | **Chemical Structure Clustering**             | Fingerprints, clustering                    | RDKit, Scikit-learn             |
# | 9  | **Molecule Dataset Cleaning Pipeline**        | Invalid SMILES, duplicates, standardization | RDKit, Pandas                   |
# | 10 | **Chemical Space Visualization**              | PCA, fingerprints, chemical space           | RDKit, Scikit-learn, Matplotlib |
#
# > Project 1 — Molecular Structure & Property Explorer
# >
# > Project 2 — Molecular Similarity & Chemical Intelligence Engine
#
#
#
# ### Level 2 — Drug Discovery Fundamentals
# ```Text
# LEVEL 2 — DRUG DISCOVERY FUNDAMENTALS
# │
# ├── PROJECT 1 : Drug Candidate Screening Platform
# │   │
# │   ├── 1. Drug-Likeness Screening
# │   └── 2. ADMET Analysis Dashboard
# │
# ├── PROJECT 2 : Virtual Screening & Compound Library Explorer
# │   │
# │   ├── 3. Molecular Fingerprint Virtual Screening
# │   ├── 4. Known Drug Similarity Search
# │   ├── 5. Compound Library Filtering
# │   └── 6. PAINS Filtering
# │
# └── PROJECT 3 : Lead Optimization & Chemical Diversity Platform
#     │
#     ├── 7. Lead Optimization Analyzer
#     ├── 8. Scaffold Extraction
#     ├── 9. Bemis–Murcko Scaffolds
#     └── 0. Chemical Diversity Analysis
# ```
# > Project 03 — Drug Candidate Screening Platform
# >
# > Project 04 — Virtual Screening & Compound Library Explorer
# >
# > Project 05 — Lead Optimization & Chemical Diversity Platform
#
#
# ### Level 3 — Machine Learning for Drug Discovery
#
# 21. **Solubility Prediction from Molecular Descriptors**
#
# 22. **LogP Prediction Model**
#
# 23. **Toxicity Prediction Model**
#
# 24. **Aqueous Solubility Classification**
#
# 25. **Drug Activity Prediction — Active vs Inactive**
#
# 26. **QSAR Model for Bioactivity Prediction**
#
# 27. **Molecular Descriptor vs Biological Activity Analysis**
#
# 28. **Random Forest Drug Activity Predictor**
#
# 29. **XGBoost QSAR Model**
#
# 30. **Graph-Based Molecular Property Predictor**
#
#
# ### Level 4 — Molecular Interaction & Virtual Screening
#
# 31. **Protein–Ligand Structure Explorer**
#
# 32. **Protein–Ligand Interaction Analyzer**
#
# 33. **Molecular Docking Pipeline**
#
# 34. **AutoDock Vina Virtual Screening Pipeline**
#
# 35. **Binding Pose Visualization**
#
# 36. **Docking Score Ranking System**
#
# 37. **Ligand–Protein Interaction Visualization**
#
# 38. **Docking Result Analysis Dashboard**
#
# 39. **Virtual Screening of a Small Compound Library**
#
# 40. **Drug Candidate Ranking System**
#
#
# ### Level 5 — Deep Learning / AI for Cheminformatics
#
# 41. **Neural Network QSAR Predictor**
#
# 42. **SMILES Classification with Transformers**
#
# 43. **Molecular Property Prediction with GNN**
#
# 44. **Molecular Graph Neural Network**
#
# 45. **GCN-Based Bioactivity Predictor**
#
# 46. **GAT-Based Molecular Property Predictor**
#
# 47. **Molecule Generation with VAE**
#
# 48. **SMILES Generation with RNN/Transformer**
#
# 49. **AI-Based Lead Optimization**
#
# 50. **AI Drug Candidate Generator**

# %% [markdown]
# | Project | Main Problem                             | Primary Data                         | Main Objects                                 |
# | ------- | ---------------------------------------- | ------------------------------------ | -------------------------------------------- |
# | **06**  | **Molecular representation + drug-likeness** [DONE] | ChEMBL, PubChem, DrugCentral | Molecules, SMILES, descriptors, fingerprints, graphs, embeddings |
# | **07**  | **Natural-product discovery** [DONE]     | NPAtlas, LOTUS, ChEMBL               | Natural products, targets, activities        |
# | **08**  | **Virtual screening + docking** [DONE]   | ZINC, PDB, ChEMBL                    | Ligands, proteins, docking poses             |
# | **09**  | **Drug-target interaction + affinity** [DONE] | BindingDB, ChEMBL, PDBBind           | Drug, target, affinity                       |
# | **10**  | Binding-site intelligence                | PDB, BioLiP, PDBBind, AlphaFold DB   | Proteins, pockets, residues, ligands         |
# | **11**  | Multi-endpoint ADMET                     | Tox21, ToxCast, ChEMBL, AqSolDB      | Molecules, ADMET endpoints                   |
# | **12**  | Explainable multimodal ADMET             | Tox21/ToxCast + molecular/graph data | Molecules + descriptors + graphs             |
# | **13**  | QSAR + lead optimization                 | BindingDB, ChEMBL                    | Molecules, activity, scaffolds, MMPs         |
# | **14**  | Generative molecular design              | ChEMBL, BindingDB, ZINC              | Molecular graphs/SMILES, targets             |
# | **15**  | Low-data orphan-target learning          | BindingDB, ChEMBL, PDB               | Sparse target–ligand datasets                |
